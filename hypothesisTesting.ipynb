# %% [markdown]
# <a href="https://colab.research.google.com/github/dgusfr/dataScience_Statistics_hypothesisTesting/blob/main/hypothesisTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistics - Hypothesis Testing
#
# ***

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('dados.csv')

# %%
dados.head()
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %% [markdown]
# # TESTES DE HIPÓTESES
# ***

# %% [markdown]
# Testes estatísticos são regras de decisão que permitem avaliar a razoabilidade das hipóteses feitas sobre os parâmetros populacionais e aceitá-las ou rejeitá-las como provavelmente verdadeiras ou falsas tendo como base uma amostra.

# %% [markdown]
# ## Teste de normalidade
# ***

# %%
from scipy.stats import normaltest

# %% [markdown]
# A função *normaltest* testa a hipótese nula $H_0$ de que a amostra é proveniente de uma distribuição normal.

# %% [markdown]
# ### Definindo a significância do teste ($\alpha$)

# %%
significancia = 0.05

# %% [markdown]
# ### Testando a variável Renda

# %%
dados.Renda.hist(bins = 50)
# Out:
# <Axes: >

# %% [markdown]
# ### <font color='red'>Critério do valor $p$</font>
#
# > ### Rejeitar $H_0$ se o valor $p\leq 0,05$

# %%
stat_test, p_valor = normaltest(dados.Renda)
print(stat_test)
print(p_valor)
# Out:
# 152380.75803960307
# 0.0

# %%
p_valor <= significancia
# Out:
# True

# %% [markdown]
# ### Testando a variável Altura

# %%
dados.Altura.hist(bins = 50)
# Out:
# <Axes: >

# %% [markdown]
# ### <font color='red'>Critério do valor $p$</font>
#
# > ### Rejeitar $H_0$ se o valor $p\leq 0,05$

# %%
stat_test, p_valor = normaltest(dados.Altura)
print(stat_test)
print(p_valor)
# Out:
# 0.19973093957002253
# 0.9049591541967501

# %%
p_valor <= significancia
# Out:
# False

# %% [markdown]
# ## Etapas de um Teste
# ***

# %% [markdown]
#  **Passo 1** - formulação das hipóteses $H_0$ e $H_1$;
#
# >  <font color='red'>Pontos importantes</font>
# > - De maneira geral, o alvo do estudo deve ser formulado como a hipótese alternativa $H_1$.
# > - A hipótese nula sempre afirma uma igualdade ou propriedade populacional, e $H_1$ a desigualdade que nega $H_0$.
# > - No caso da hipótese nula $H_0$ a igualdade pode ser representada por uma igualdade simples "$=$" ou por "$\geq$" e "$\leq$". Sempre complementar ao estabelecido pela hipótese alternativa.
# > - A hipótese alternativa $H_1$ deve definir uma desigualdade que pode ser uma diferença simples "$\neq$" ou dos tipos "$>$" e "$<$".
#
#
#  **Passo 2** - escolha da distribuição amostral adequada;
#
# >  <font color='red'>Pontos importantes</font>
# > - Quando o tamanho da amostra tiver 30 elementos ou mais, deve-se utilizar a distribuição normal, como estabelecido pelo **teorema do limite central**.
# > - Para um tamanho de amostra menor que 30 elementos, e se pudermos afirmar que a população se distribui aproximadamente como uma normal e o desvio padrão populacional for conhecido, deve-se utilizar a distribuição normal.
# > - Para um tamanho de amostra menor que 30 elementos, e se pudermos afirmar que a população se distribui aproximadamente como uma normal e o desvio padrão populacional for desconhecido, deve-se utilizar a distribuição t de Student.
#
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img003.png' width=70%>
#
#
# Definindo as regiões de aceitação e rejeição das hipóteses (os valores mais freqüentes são 10%, 5% e 1%);
#
# >  <font color='red'>Pontos importantes</font>
# > - O **nível de confiança** ($1 - \alpha$) representa a probabilidade de acerto da estimativa. De forma complementar o **nível de significância** ($\alpha$) expressa a probabilidade de erro da estimativa.
# >
# > ![Níveis de Confiança e significância](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img001.png)
# >
# > - O **nível de confiança** representa o grau de confiabilidade do resultado da estimativa estar dentro de determinado intervalo. Quando fixamos em uma pesquisa um **nível de confiança** de 95%, por exemplo, estamos assumindo que existe uma probabilidade de 95% dos resultados da pesquisa representarem bem a realidade, ou seja, estarem corretos.
# >
# > ![Áreas de Aceitação e Rejeição](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img002.png)
#
#  **Passo 4** - cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste;
#
# >  <font color='red'>Pontos importantes</font>
# > - Nos testes paramétricos, distância relativa entre a estatística amostral e o valor alegado como provável.
# > - Neste passo são obtidas as estatísticas amostrais necessárias à execução do teste (média, desvio-padrão, graus de liberdade etc.)
#
#
#  **Passo 5** - Aceitação ou rejeição da hipótese nula.
#
# >  <font color='red'>Pontos importantes</font>
# > - No caso de o intervalo de aceitação conter a estatística-teste, aceita-se $H_0$ como estatisticamente válido e rejeita-se $H_1$ como tal.
# > - No caso de o intervalo de aceitação não conter a estatística-teste, rejeita-se $H_0$ e aceita-se $H_1$ como provavelmente verdadeira.
# > - A aceitação também se verifica com a probabilidade de cauda (p-valor): se maior que $\alpha$, aceita-se $H_0$.

# %% [markdown]
# ---

# %% [markdown]
# ## Testes Paramétricos
# ***

# %% [markdown]
# Quando um teste assume determinadas premissas sobre como os parâmetros de uma população se distribuem, estamos trabalhando com **Testes Paramétricos**.

# %% [markdown]
# ### Teste Bicaudal
# ***

# %% [markdown]
# A empresa **Suco Bom** produz **sucos de frutas em embalagens de 500 ml**. Seu processo de produção é quase todo automatizado e as embalagens de sucos são preenchidas por uma máquina que às vezes apresenta um certo desajuste, levando a erros no preenchimento das embalagens para mais ou menos conteúdo. Quando o volume médio cai abaixo de 500 ml, a empresa se preocupa em perder vendas e ter problemas com os orgãos fiscalizadores. Quando o volume passa de 500 ml, a empresa começa a se preocupar com prejuízos no processo de produção.
#
# O setor de controle de qualidade da empresa **Suco Bom** extrai, periodicamente, **amostras de 50 embalagens** para monitorar o processo de produção. Para cada amostra, é realizado um **teste de hipóteses** para avaliar se o maquinário se desajustou. A equipe de controle de qualidade assume um **nível de significância de 5%**.
#
# Suponha agora que uma **amostra de 50 embalagens** foi selecionada e que a **média amostral observada foi de 503,24 ml**. **Esse valor de média amostral é suficientemente maior que 500 ml para nos fazer rejeitar a hipótese de que a média do processo é de 500 ml ao nível de significância de 5%?**

# %% [markdown]
# ---

# %% [markdown]
# O **teste bicaudal** é muito utilizado em **testes de qualidade**, como o apresentado em nosso problema acima. Outro exemplo é a avaliação de peças que devem ter um encaixe perfeito (porcas e parafusos, chaves e fechaduras).

# %% [markdown]
# ![Teste Bicaudal](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img005.png)

# %% [markdown]
# ---

# %% [markdown]
# <FONT SIZE=5> Dados do problema </FONT>

# %%
amostra = [509, 505, 495, 510, 496, 509, 497, 502, 503, 505,
           501, 505, 510, 505, 504, 497, 506, 506, 508, 505,
           497, 504, 500, 498, 506, 496, 508, 497, 503, 501,
           503, 506, 499, 498, 509, 507, 503, 499, 509, 495,
           502, 505, 504, 509, 508, 501, 505, 497, 508, 507]

# %%
amostra = pd.DataFrame(amostra, columns=['Amostra'])
amostra.head()
# Out:
#    Amostra
# 0      509
# 1      505
# 2      495
# 3      510
# 4      496

# %%
media_amostra = amostra.mean()[0]
media_amostra
# Out:
# <ipython-input-14-8891f5639f6a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   media_amostra = amostra.mean()[0]
# 503.24

# %%
desvio_padrao_amostra = amostra.std()[0]
desvio_padrao_amostra
# Out:
# <ipython-input-15-efe6a624f5f0>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   desvio_padrao_amostra = amostra.std()[0]
# 4.483803050527347

# %%
media = 500
significancia = 0.05
confianca = 1 - significancia
n = 50

# %% [markdown]
# <FONT SIZE=5> **Passo 1** - formulação das hipóteses $H_0$ e $H_1$ </FONT>
#
# <font color='red'>Lembre-se, a hipótese nula sempre contém a alegação de igualdade</font>

# %% [markdown]
# <FONT SIZE=5> $H_0: \mu = 500$ </FONT>
#
# <FONT SIZE=5> $H_1: \mu \neq 500$ </FONT>

# %% [markdown]
# ---

# %% [markdown]
# <FONT SIZE=5> **Passo 2** - escolha da distribuição amostral adequada </FONT>
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img003.png' width=70%>

# %% [markdown]
# <FONT SIZE=5> O tamanho da amostra é maior que 30? </FONT><BR>
# <FONT SIZE=4> Resp.: Sim </FONT><BR>
# <FONT SIZE=5> O desvio padrão populacional é conhecido? </FONT><BR>
# <FONT SIZE=4> Resp.: Não </FONT>

# %% [markdown]
# <FONT SIZE=5> **Passo 3** - fixação da significância do teste ($\alpha$) </FONT>

# %%
from scipy.stats import norm

# %%
probabilidade = (0.5 + (confianca / 2))
probabilidade
# Out:
# 0.975

# %% [markdown]
# A probabilidade a cima é o valor de Z para 1,96

# %% [markdown]
# <FONT SIZE=5> Obtendo $z_{\alpha/2}$ </FONT>

# %%
z_alpha_2 = norm.ppf(probabilidade)
z_alpha_2
# Out:
# 1.959963984540054

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img006.png)

# %% [markdown]
# ---

# %% [markdown]
# <FONT SIZE=5> **Passo 4** - cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste </FONT>
#
# <FONT SIZE=5> $$z = \frac{\bar{x} - \mu_0}{\frac{s}{\sqrt{n}}}$$ </FONT>

# %%
z = (media_amostra - media) / (desvio_padrao_amostra / np.sqrt(n))
z
# Out:
# 5.109559775991877

# %% [markdown]
# ![Estatística-Teste](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img007.png)

# %% [markdown]
# Em **z = 5,11** é a area de rejeição da hipotese nulo, ou seja, estamos rejeitando a hipotese de que a media é igual a **500** com um nivel de significancia  de **5%**

# %% [markdown]
# <FONT SIZE=5> **Passo 5** - Aceitação ou rejeição da hipótese nula </FONT>

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img013.png' width=90%>

# %% [markdown]
# #### <FONT SIZE=5> Critério do valor crítico Z</FONT>
#
# <FONT SIZE=5> Teste Bicaudal </FONT><BR>
# <FONT SIZE=5> Rejeitar $H_0$ se $z \leq -z_{\alpha / 2}$ ou se $z \geq z_{\alpha / 2}$ </FONT>

# %%
z <= -z_alpha_2
# Out:
# False

# %%
z >= z_alpha_2
# Out:
# True

# %% [markdown]
# <FONT SIZE=5> Conclusão:</FONT><FONT SIZE=4> Como a média amostral $\bar{x}$ é significativamente maior que 500 ml, rejeitamos $H_0$. Neste caso, devem ser tomadas providências para ajustar o maquinário que preenche as embalagens. </FONT>

# %% [markdown]
# ***
# #### <FONT SIZE=5> Critério do $p$-valor </FONT><BR>
#
# <FONT SIZE=4> Teste Bicaudal </FONT><BR>
# <FONT SIZE=4> Rejeitar $H_0$ se o valor $p \leq \alpha$ </FONT>

# %%
p_valor = 2 * (1 - norm.cdf(z))
p_valor
# Out:
# 3.2291031715203644e-07

# %%
p_valor = 2 * (norm.sf(z))
p_valor
# Out:
# 3.229103172445718e-07

# %%
p_valor <= significancia
# Out:
# True

# %% [markdown]
# No codigo a cima comparamos o pvalor com a significancia de 0,05, o que retorna true, ou seja, rejeitamos H0 para esses parametros de pvalor.

# %%
from statsmodels.stats.weightstats import ztest

# %%
ztest(x1 = amostra, value = media)
# Out:
# (array([5.10955978]), array([3.22910317e-07]))

# %%
from statsmodels.stats.weightstats import DescrStatsW

# %%
test = DescrStatsW(amostra)

# %%
z, p_valor = test.ztest_mean(value = media)
print(z[0])
print(p_valor[0])
# Out:
# 5.109559775991874
# 3.2291031724457596e-07

# %% [markdown]
# ### Teste Unicaudal
# ***

# %% [markdown]
# Um famoso fabricante de refrigerantes alega que uma lata de 350 ml de seu principal produto contém, **no máximo**, **37 gramas de açúcar**. Esta alegação nos leva a entender que a quantidade média de açúcar em uma lata de refrigerante deve ser **igual ou menor que 37 g**.
#
# Um consumidor desconfiado e com conhecimentos em inferência estatística resolve testar a alegação do fabricante e seleciona, aleatóriamente, em um conjunto de estabelecimentos distintos, **uma amostra de 25 latas** do refrigerante em questão. Utilizando o equipamento correto o consumidor obteve as quantidades de açúcar em todas as 25 latas de sua amostra.
#
# **Assumindo que essa população se distribua aproximadamente como uma normal e considerando um nível de significância de 5%, é possível aceitar como válida a alegação do fabricante?**

# %% [markdown]
# <FONT SIZE=5> Construindo tabela $t$ de Student </FONT>

# %%
import pandas as pd
from scipy.stats import t as t_student

tabela_t_student = pd.DataFrame(
    [],
    index=[i for i in range(1, 31)],
    columns = [i / 100 for i in range(10, 0, -1)]
)

for index in tabela_t_student.index:
    for column in tabela_t_student.columns:
        tabela_t_student.loc[index, column] = t_student.ppf(1 - float(column) / 2, index)

index=[('Graus de Liberdade (n - 1)', i) for i in range(1, 31)]
tabela_t_student.index = pd.MultiIndex.from_tuples(index)

columns = [("{0:0.3f}".format(i / 100), "{0:0.3f}".format((i / 100) / 2)) for i in range(10, 0, -1)]
tabela_t_student.columns = pd.MultiIndex.from_tuples(columns)

tabela_t_student.rename_axis(['Bicaudal', 'Unicaudal'], axis=1, inplace = True)

tabela_t_student
# Out:
# Bicaudal                          0.100     0.090     0.080     0.070  \
# Unicaudal                         0.050     0.045     0.040     0.035
# Graus de Liberdade (n - 1) 1   6.313752  7.026366  7.915815  9.057887
#                            2   2.919986  3.103977  3.319764  3.578247
#                            3   2.353363  2.470807  2.605427  2.762599
#                            4   2.131847    2.2261  2.332873  2.455892
#                            5   2.015048  2.097837  2.190958  2.297392
#                            6    1.94318  2.019201  2.104306  2.201059
#                            7   1.894579  1.966153  2.046011  2.136453
#                            8   1.859548  1.927986  2.004152  2.090166
#                            9   1.833113  1.899222  1.972653  2.055395
#                            10  1.812461  1.876774  1.948099  2.028327
#                            11  1.795885  1.858772  1.928427  2.006663
# ...

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img004.png' width='250px'>
#
# As células da tabela acima são valores de $t$ para uma área ou probabilidade na cauda superior da distribuição $t$.

# %% [markdown]
# ---

# %% [markdown]
# Os **testes unicaudais** verificam as variáveis em relação a um piso ou a um teto e avaliam os valores máximos ou mínimos esperados para os parâmetros em estudo e a chance de as estatísticas amostrais serem inferiores ou superiores a dado limite.

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img008.png' width='700px'>

# %% [markdown]
# <FONT SIZE=5> Dados do problema </FONT>

# %%
amostra = [37.27, 36.42, 34.84, 34.60, 37.49,
           36.53, 35.49, 36.90, 34.52, 37.30,
           34.99, 36.55, 36.29, 36.06, 37.42,
           34.47, 36.70, 35.86, 36.80, 36.92,
           37.04, 36.39, 37.32, 36.64, 35.45]

# %%
amostra = pd.DataFrame(amostra, columns=['Amostra'])
amostra
# Out:
#     Amostra
# 0     37.27
# 1     36.42
# 2     34.84
# 3     34.60
# 4     37.49
# 5     36.53
# 6     35.49
# 7     36.90
# 8     34.52
# 9     37.30
# 10    34.99
# 11    36.55
# 12    36.29
# 13    36.06
# 14    37.42
# 15    34.47
# 16    36.70
# 17    35.86
# 18    36.80
# 19    36.92
# 20    37.04
# 21    36.39
# 22    37.32
# 23    36.64
# 24    35.45

# %%
media_amostra = amostra.mean()[0]
media_amostra
# Out:
# <ipython-input-34-8891f5639f6a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   media_amostra = amostra.mean()[0]
# 36.2504

# %%
desvio_padrao_amostra = amostra.std()[0]
desvio_padrao_amostra
# Out:
# <ipython-input-35-efe6a624f5f0>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   desvio_padrao_amostra = amostra.std()[0]
# 0.9667535018469453

# %%
media = 37
significancia = 0.05
confianca = 1 - significancia
n = 25
graus_de_liberdade = n - 1

# %% [markdown]
# <FONT SIZE=5> **Passo 1** - formulação das hipóteses $H_0$ e $H_1$ </FONT>

# %% [markdown]
# <font color='red'>Lembre-se, a hipótese nula sempre contém a alegação de igualdade</font>

# %% [markdown]
# <FONT SIZE=5> $H_0: \mu \leq 37$ </FONT><BR>
# <FONT SIZE=5> $H_1: \mu > 37$ </FONT>

# %% [markdown]
# ---

# %% [markdown]
# <FONT SIZE=5> **Passo 2** - escolha da distribuição amostral adequada </FONT>
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img003.png' width=70%>

# %% [markdown]
# <FONT SIZE=4> O tamanho da amostra é maior que 30? </FONT><BR>
# <FONT SIZE=4> Resp.: Não </FONT><BR>
#
# <FONT SIZE=4> Podemos afirmar que a população se distribui aproximadamente como uma normal? </FONT><BR>
# <FONT SIZE=4> Resp.: Sim </FONT><BR>
#
# <FONT SIZE=4> O desvio padrão populacional é conhecido? </FONT><BR>
# <FONT SIZE=4> Resp.: Não </FONT>

# %% [markdown]
# ---

# %% [markdown]
# <FONT SIZE=5> **Passo 3** - fixação da significância do teste ($\alpha$) </FONT>

# %%
from scipy.stats import t as t_student

# %%
tabela_t_student[22:25]
# Out:
# Bicaudal                          0.100     0.090     0.080     0.070  \
# Unicaudal                         0.050     0.045     0.040     0.035
# Graus de Liberdade (n - 1) 23  1.713872  1.769907  1.831567  1.900307
#                            24  1.710882  1.766675  1.828051  1.896457
#                            25  1.708141  1.763711  1.824828  1.892928
#
# Bicaudal                          0.060     0.050     0.040     0.030  \
# Unicaudal                         0.030     0.025     0.020     0.015
# Graus de Liberdade (n - 1) 23  1.978249  2.068658  2.176958  2.313231
#                            24  1.973994  2.063899  2.171545  2.306913
#                            25  1.970095  2.059539  2.166587   2.30113
#
# Bicaudal                          0.020     0.010
# Unicaudal                         0.010     0.005
# Graus de Liberdade (n - 1) 23  2.499867  2.807336
#                            24  2.492159   2.79694
#                            25  2.485107  2.787436

# %% [markdown]
# <FONT SIZE=5> Obtendo $t_{\alpha}$ </FONT>

# %%
t_alpha = t_student.ppf(confianca, graus_de_liberdade)
t_alpha
# Out:
# 1.7108820799094275

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img009.png)

# %% [markdown]
# ---

# %% [markdown]
# <FONT SIZE=5> **Passo 4** - cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste </FONT><BR>
# <FONT SIZE=5> $$t = \frac{\bar{x} - \mu_0}{\frac{s}{\sqrt{n}}}$$ </FONT>

# %%
t = (media_amostra - media) / (desvio_padrao_amostra / np.sqrt(n))
t
# Out:
# -3.876893119952082

# %% [markdown]
# ![Estatística-Teste](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img010.png)

# %% [markdown]
# ---

# %% [markdown]
# <FONT SIZE=5> **Passo 5** - Aceitação ou rejeição da hipótese nula </FONT>

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img013.png' width=90%>

# %% [markdown]
# #### Critério do valor crítico
#
# > ### Teste Unicaudal Superior
# > ### Rejeitar $H_0$ se $t \geq t_{\alpha}$

# %%
t >= t_alpha
# Out:
# False

# %% [markdown]
# <FONT SIZE=5> Conclusão:</FONT> <FONT SIZE=4>Com um nível de confiança de 95% não podemos rejeitar $H_0$, ou seja, a alegação do fabricante é verdadeira.</FONT>

# %% [markdown]
# #### Critério do valor $p$
#
# > ### Teste Unicaudal Superior
# > ### Rejeitar $H_0$ se o valor $p\leq\alpha$

# %%
t
# Out:
# -3.876893119952082

# %%
p_valor = t_student.sf(t, df = 24)
p_valor
# Out:
# 0.9996406170303819

# %%
p_valor <= significancia
# Out:
# False

# %%
from statsmodels.stats.weightstats import DescrStatsW

# %%
test = DescrStatsW(amostra)

# %%
t, p_valor, df = test.ttest_mean(value = media, alternative = 'larger')
print(t[0])
print(p_valor[0])
print(df)
# Out:
# -3.8768931199520447
# 0.9996406170303819
# 24.0

# %%
p_valor[0] <= significancia
# Out:
# False

# %% [markdown]
# ---

# %% [markdown]
# ## Testes para Duas Amostras
# ***

# %% [markdown]
# Problema

# %% [markdown]
# Em nosso dataset temos os rendimento dos chefes de domicílio obtidos da Pesquisa Nacional por Amostra de Domicílios - PNAD no ano de 2015. Um problema bastante conhecido em nosso país diz respeito a desigualdade de renda, principalmente entre homens e mulheres.
#
# Duas amostras aleatórias, uma de **500 homens** e outra com **500 mulheres**, foram selecionadas em nosso dataset. Com o objetivo de comprovar tal desigualdade, **teste a igualdade das médias** entre estas duas amostras com um nível de **significância de 1%**.

# %% [markdown]
# ---

# %% [markdown]
# É possível também utilizar testes de hipóteses para comparar duas diferentes amostras. Neste tipo de teste se deseja decidir se uma amostra é diferente da outra.

# %% [markdown]
# ### Seleção das amostras

# %%
homens = dados.query('Sexo == 0').sample(n = 500, random_state = 101).Renda

# %%
mulheres = dados.query('Sexo == 1').sample(n = 500, random_state = 101).Renda

# %% [markdown]
# ### Dados do problema

# %%
media_amostra_M = mulheres.mean()
media_amostra_M
# Out:
# 1357.528

# %%
desvio_padrao_amostra_M = mulheres.std()
desvio_padrao_amostra_M
# Out:
# 1569.9011907484578

# %%
media_amostra_H = homens.mean()
media_amostra_H
# Out:
# 2142.608

# %%
desvio_padrao_amostra_H = homens.std()
desvio_padrao_amostra_H
# Out:
# 2548.050802499875

# %%
significancia = 0.01
confianca = 1 - significancia
n_M = 500
n_H = 500
D_0 = 0

# %% [markdown]
# ---

# %% [markdown]
# <font size=5> Passo 1 - Formulação das hipóteses $H_0$ e $H_1$ </font>
# <font size=5 color='red'>Lembre-se, a hipótese nula sempre contém a alegação de igualdade</font>

# %% [markdown]
# <font size=5> $\mu_1 \Rightarrow$ Média das rendas dos chefes de domicílios do sexo masculino</font>
# <font size=5> $\mu_2 \Rightarrow$ Média das rendas dos chefes de domicílios do sexo feminino</font>
#
# <font size=5>
# \begin{cases}
# H_0: \mu_1 \leq \mu_2 \\
# H_1: \mu_1 > \mu_2
# \end{cases}
# </font>
#
# <font size=5> ou </font>
#
# <font size=5>
# \begin{cases}
# H_0: \mu_1 - \mu_2 \leq 0 \\
# H_1: \mu_1 - \mu_2 > 0
# \end{cases}
# </font>

# %% [markdown]
# ---

# %% [markdown]
# <font size=5> Passo 2 - Escolha da distribuição amostral adequada </font>
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img003.png' width=70%>
#
# <font color='red'>Observação importante</font>
# > Em testes que envolvam duas amostras com o emprego da tabela $t$ de Student, o número de graus de liberdade será sempre igual a $n_1 + n_2 - 2$

# %% [markdown]
# <font size=5> O tamanho da amostra é maior que 30? </font>
# <font size=5> Resp.: Sim </font>
#
# <font size=5> O desvio padrão populacional é conhecido? </font>
# <font size=5> Resp.: Não </font>

# %% [markdown]
# ---

# %% [markdown]
# <font size=5> **Passo 3** - Fixação da significância do teste ($\alpha$) </font>

# %%
probabilidade = confianca
probabilidade
# Out:
# 0.99

# %%
z_alpha = norm.ppf(probabilidade)
z_alpha.round(2)
# Out:
# 2.33

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img011.png)

# %% [markdown]
# ---

# %% [markdown]
# <font size=5> **Passo 4** - Cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste </font>
#
# $$z = \frac{(\bar{x_1} - \bar{x_2})-D_0}{\sqrt{\frac{s_1^2}{n_1} + \frac{s_2^2}{n_2}}}$$

# %%
numerador = (media_amostra_H - media_amostra_M) - D_0

denominador = np.sqrt((desvio_padrao_amostra_H ** 2 / n_H) + (desvio_padrao_amostra_M ** 2 / n_M))

z = numerador / denominador

z
# Out:
# 5.86562005776475

# %% [markdown]
# ![Estatística-Teste](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img012.png)

# %% [markdown]
# ---

# %% [markdown]
# <font size=5> **Passo 5** - Aceitação ou rejeição da hipótese nula </font>

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img014.png' width=90%>

# %% [markdown]
# ### <font color='red'>Critério do valor crítico</font>
#
# > ### Teste Unicaudal
# > ### Rejeitar $H_0$ se $z \geq z_{\alpha}$

# %%
z >= z_alpha
# Out:
# True

# %% [markdown]
# <font color='green'>Conclusão: Com um nível de confiança de 99% rejeitamos $H_0$, isto é, concluímos que a média das rendas dos chefes de domicílios do sexo masculino é maior que a média das rendas das chefes de domicílios do sexo feminino. Confirmando a alegação de desigualdade de renda entre os sexos.</font>

# %% [markdown]
# ### <font color='red'>Critério do valor $p$</font>
#
# > ### Teste Unicaudal
# > ### Rejeitar $H_0$ se o valor $p\leq\alpha$

# %% [markdown]
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.DescrStatsW.html
#
# https://www.statsmodels.org/dev/generated/statsmodels.stats.weightstats.CompareMeans.ttest_ind.html

# %%
from statsmodels.stats.weightstats import DescrStatsW, CompareMeans

# %%
test_H = DescrStatsW(homens)

# %%
test_M = DescrStatsW(mulheres)

# %%
test_A = test_H.get_compare(test_M)

# %%
z, p_valor = test_A.ztest_ind(alternative='larger', value=0)
p_valor
# Out:
# 2.2372867859458255e-09

# %%
test_B = CompareMeans(test_H, test_M)

# %%
z, p_valor = test_B.ztest_ind(alternative='larger', value=0)
p_valor
# Out:
# 2.2372867859458255e-09

# %%
p_valor <= significancia
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# # TESTES NÃO PARAMÉTRICOS
# ***

# %% [markdown]
# O trabalho com pequenas amostras pode levar a não aceitação da validade do teorema central do limite e também na impossibilidade de fazer suposições sobre a distribuição da variável avaliada. Quando isso ocorre torna-se necessária a aplicação de testes não paramétricos. Nos testes não paramétricos, não fazemos hipóteses sobre a distribuição (de probabilidade) das quais as observações são extraídas.

# %% [markdown]
# ## Problema

# %% [markdown]
# Antes de cada partida do campeonato nacional de futebol, as moedas utilizadas pelos árbitros devem ser verificadas para se ter certeza de que não são viciadas, ou seja, que não tendam para determinado resultado. Para isso um teste simples deve ser realizado antes de cada partida. Este teste consiste em lançar a moeda do jogo **50 vezes** e contar as frequências de **CARAS** e **COROAS** obtidas. A tabela abaixo mostra o resultado obtido no experimento:
#
# ||CARA|COROA|
# |-|-|-|
# |Observado|17|33|
# |Esperado|25|25|
#
# A um **nível de significância de 5%**, é possível afirmar que a moeda não é honesta, isto é, que a moeda apresenta uma probabilidade maior de cair com a face **CARA** voltada para cima?

# %% [markdown]
# ## Teste do Qui-Quadrado ( $\chi^2$)
# ***

# %% [markdown]
# Também conhecido como teste de adequação ao ajustamento, seu nome se deve ao fato de utilizar uma variável estatística padronizada, representada pela letra grega qui ( $\chi$) elevada ao quadrado. A tabela com os valores padronizados e como obtê-la podem ser vistos logo abaixo.
#
# O teste do $\chi^2$ testa a hipótese nula de não haver diferença entre as frequências observadas de um determinado evento e as frequências que são realmente esperadas para este evento.
#
# Os passos de aplicação do teste são bem parecidos aos vistos para os testes paramétricos.
#
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img017.png)

# %% [markdown]
# ### Construindo tabela $\chi^2$
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi.html

# %%
import pandas as pd
from scipy.stats import chi

tabela_t_chi_2 = pd.DataFrame(
    [],
    index=[i for i in range(1, 31)],
    columns = [0.005, 0.01, 0.025, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.975, 0.95, 0.99, 0.995]
)

for index in tabela_t_chi_2.index:
    for column in tabela_t_chi_2.columns:
        tabela_t_chi_2.loc[index, column] = "{0:0.4f}".format(chi.ppf(float(column), index)**2)

tabela_t_chi_2.index.name='Graus de Liberdade'
tabela_t_chi_2.rename_axis(['p'], axis=1, inplace = True)

tabela_t_chi_2
# Out:
# p                     0.005    0.010    0.025    0.050    0.100    0.250  \
# Graus de Liberdade
# 1                    0.0000   0.0002   0.0010   0.0039   0.0158   0.1015
# 2                    0.0100   0.0201   0.0506   0.1026   0.2107   0.5754
# 3                    0.0717   0.1148   0.2158   0.3518   0.5844   1.2125
# 4                    0.2070   0.2971   0.4844   0.7107   1.0636   1.9226
# 5                    0.4117   0.5543   0.8312   1.1455   1.6103   2.6746
# 6                    0.6757   0.8721   1.2373   1.6354   2.2041   3.4546
# 7                    0.9893   1.2390   1.6899   2.1673   2.8331   4.2549
# 8                    1.3444   1.6465   2.1797   2.7326   3.4895   5.0706
# 9                    1.7349   2.0879   2.7004   3.3251   4.1682   5.8988
# 10                   2.1559   2.5582   3.2470   3.9403   4.8652   6.7372
# 11                   2.6032   3.0535   3.8157   4.5748   5.5778   7.5841
# 12                   3.0738   3.5706   4.4038   5.2260   6.3038   8.4384
# ...

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img016.png' width='250px'>
#
# Tabela com os valores de $\chi_p^2$ em função dos graus de liberdade $(n - 1)$ e de $p = P(\chi^2 \leq \chi_p^2)$

# %% [markdown]
# ## <font color='red'>Problema</font>

# %% [markdown]
# Antes de cada partida do campeonato nacional de futebol, as moedas utilizadas pelos árbitros devem ser verificadas para se ter certeza de que não são viciadas, ou seja, que não tendam para determinado resultado. Para isso um teste simples deve ser realizado antes de cada partida. Este teste consiste em lançar a moeda do jogo **50 vezes** e contar as frequências de **CARAS** e **COROAS** obtidas. A tabela abaixo mostra o resultado obtido no experimento:
#
# ||CARA|COROA|
# |-|-|-|
# |Observado|17|33|
# |Esperado|25|25|
#
# A um **nível de significância de 5%**, é possível afirmar que a moeda não é honesta, isto é, que a moeda apresenta uma probabilidade maior de cair com a face **CARA** voltada para cima?

# %% [markdown]
# ---

# %% [markdown]
# ### Dados do problema

# %%
F_Observada = [17, 33]
F_Esperada = [25, 25]
significancia = 0.05
confianca = 1 - significancia
k = 2 # Número de eventos possíveis
graus_de_liberdade = k - 1

# %% [markdown]
# ### **Passo 1**
#
# Formulação das hipóteses $H_0$ e $H_1$
#
# #### <font color='red'>Lembre-se, a hipótese nula sempre contém a alegação de igualdade</font>

# %% [markdown]
#  $H_0: F_{CARA} = F_{COROA}$
#
#  $H_1: F_{CARA} \neq F_{COROA}$

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 2**
#
# Fixação da significância do teste ($\alpha$)

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi.html

# %%
from scipy.stats import chi

# %%
tabela_t_chi_2[:3]
# Out:
# p                    0.005   0.010   0.025   0.050   0.100   0.250   0.500  \
# Graus de Liberdade
# 1                   0.0000  0.0002  0.0010  0.0039  0.0158  0.1015  0.4549
# 2                   0.0100  0.0201  0.0506  0.1026  0.2107  0.5754  1.3863
# 3                   0.0717  0.1148  0.2158  0.3518  0.5844  1.2125  2.3660
#
# p                    0.750   0.900   0.975   0.950    0.990    0.995
# Graus de Liberdade
# 1                   1.3233  2.7055  5.0239  3.8415   6.6349   7.8794
# 2                   2.7726  4.6052  7.3778  5.9915   9.2103  10.5966
# 3                   4.1083  6.2514  9.3484  7.8147  11.3449  12.8382

# %% [markdown]
#  Obtendo $\chi_{\alpha}^2$

# %%
chi_2_alpha = chi.ppf(confianca, graus_de_liberdade) ** 2
chi_2_alpha
# Out:
# 3.8414588206941245

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img018.png)

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 3**
#
# Cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste
#
# # $$\chi^2 = \sum_{i=1}^{k}{\frac{(F_{i}^{Obs} - F_{i}^{Esp})^2}{F_{i}^{Esp}}}$$
#
# Onde
#
# $F_{i}^{Obs}$ = frequência observada para o evento $i$
#
# $F_{i}^{Esp}$ = frequência esperada para o evento $i$
#
# $k$ = total de eventos possíveis

# %%
chi_2 = ( (F_Observada[0] - F_Esperada[0]) ** 2 /  F_Esperada[0] ) + ( (F_Observada[1] - F_Esperada[1]) ** 2 /  F_Esperada[1] )
chi_2
# Out:
# 5.12

# %%
chi_2 = 0
for i in range(k):
  chi_2 += (F_Observada[i] - F_Esperada[i]) ** 2 /  F_Esperada[i]

chi_2
# Out:
# 5.12

# %% [markdown]
# ![Estatística-Teste](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img019.png)

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 4**
#
# Aceitação ou rejeição da hipótese nula

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img020.png' width=80%>

# %% [markdown]
# ### <font color='red'>Critério do valor crítico</font>
#
# > ### Rejeitar $H_0$ se $\chi_{teste}^2 > \chi_{\alpha}^2$

# %%
chi_2 > chi_2_alpha
# Out:
# True

# %% [markdown]
#  <font color='green'>Conclusão: Com um nível de confiança de 95% rejeitamos a hipótese nula ($H_0$) e concluímos que as frequências observadas e esperadas são discrepantes, ou seja, a moeda não é honesta e precisa ser substituída.</font>

# %% [markdown]
# ### <font color='red'>Critério do valor $p$</font>
#
# > ### Rejeitar $H_0$ se o valor $p\leq\alpha$

# %%
chi_2
# Out:
# 5.12

# %%
raiz_chi_2 = np.sqrt(chi_2)
raiz_chi_2
# Out:
# 2.262741699796952

# %%
p_valor = chi.sf(raiz_chi_2, df=1)
p_valor
# Out:
# 0.023651616655356

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chisquare.html

# %%
from scipy.stats import chisquare

# %%
chi_2, p_valor = chisquare(f_obs=F_Observada, f_exp=F_Esperada)
print(chi_2)
print(p_valor)
# Out:
# 5.12
# 0.023651616655356

# %%
p_valor <= significancia
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Teste Wilcoxon
# ### Comparação de duas populações - amostras dependentes
# ***

# %% [markdown]
# Empregado quando se deseja comparar duas amostras relacionadas, amostras emparelhadas. Pode ser aplicado quando se deseja testar a diferença de duas condições, isto é, quando um mesmo elemento é submetido a duas medidas.

# %% [markdown]
# ### Dados do problema

# %%
fumo = {
    'Antes': [39, 25, 24, 50, 13, 52, 21, 29, 10, 22, 50, 15, 36, 39, 52, 48, 24, 15, 40, 41, 17, 12, 21, 49, 14, 55, 46, 22, 28, 23, 37, 17, 31, 49, 49],
    'Depois': [16, 8, 12, 0, 14, 16, 13, 12, 19, 17, 17, 2, 15, 10, 20, 13, 0, 4, 16, 18, 16, 16, 9, 9, 18, 4, 17, 0, 11, 14, 0, 19, 2, 9, 6]
}
significancia = 0.05
confianca = 1 - significancia
n = 35

# %%
fumo = pd.DataFrame(fumo)
fumo.head()
# Out:
#    Antes  Depois
# 0     39      16
# 1     25       8
# 2     24      12
# 3     50       0
# 4     13      14

# %%
media_antes = fumo.Antes.mean()
media_antes
# Out:
# 31.857142857142858

# %%
media_depois = fumo.Depois.mean()
media_depois
# Out:
# 11.2

# %% [markdown]
# ### **Passo 1**
#
# Formulação das hipóteses $H_0$ e $H_1$
#
# #### <font color='red'>Lembre-se, a hipótese nula sempre contém a alegação de igualdade</font>

# %% [markdown]
#  $H_0: \mu_{antes} = \mu_{depois}$
#
#  $H_1: \mu_{antes} > \mu_{depois}$

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 2**
# Escolha da distribuição amostral adequada

# %% [markdown]
#  O tamanho da amostra é maior que 20?
#  Resp.: Sim

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 3**
#
# Fixação da significância do teste ($\alpha$)

# %% [markdown]
# Obtendo $z_{\alpha/2}$

# %%
probabilidade = (0.5 + (confianca / 2))
probabilidade
# Out:
# 0.975

# %%
z_alpha_2 = norm.ppf(probabilidade)
z_alpha_2.round(2)
# Out:
# 1.96

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img006.png)

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 4**
#
# Cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste
#
#  $$Z = \frac{T - \mu_T}{\sigma_T}$$
#
# Onde
#
#  $T$ = menor das somas de postos de mesmo sinal
#
#  $$\mu_T = \frac{n(n+1)}{4}$$
#  $$\sigma_T = \sqrt{\frac{n(n + 1)(2n + 1)}{24}}$$

# %% [markdown]
#  Construindo a tabela com os postos

# %%
fumo
# Out:
#     Antes  Depois
# 0      39      16
# 1      25       8
# 2      24      12
# 3      50       0
# 4      13      14
# 5      52      16
# 6      21      13
# 7      29      12
# 8      10      19
# 9      22      17
# 10     50      17
# 11     15       2
# 12     36      15
# 13     39      10
# 14     52      20
# 15     48      13
# 16     24       0
# 17     15       4
# 18     40      16
# 19     41      18
# 20     17      16
# 21     12      16
# 22     21       9
# 23     49       9
# 24     14      18
# 25     55       4
# 26     46      17
# 27     22       0
# 28     28      11
# 29     23      14
# 30     37       0
# 31     17      19
# 32     31       2
# 33     49       9
# 34     49       6

# %%
fumo['Dif'] = fumo.Depois - fumo.Antes
fumo
# Out:
#     Antes  Depois  Dif
# 0      39      16  -23
# 1      25       8  -17
# 2      24      12  -12
# 3      50       0  -50
# 4      13      14    1
# 5      52      16  -36
# 6      21      13   -8
# 7      29      12  -17
# 8      10      19    9
# 9      22      17   -5
# 10     50      17  -33
# 11     15       2  -13
# 12     36      15  -21
# 13     39      10  -29
# 14     52      20  -32
# 15     48      13  -35
# 16     24       0  -24
# 17     15       4  -11
# 18     40      16  -24
# 19     41      18  -23
# 20     17      16   -1
# 21     12      16    4
# 22     21       9  -12
# 23     49       9  -40
# 24     14      18    4
# 25     55       4  -51
# 26     46      17  -29
# 27     22       0  -22
# 28     28      11  -17
# 29     23      14   -9
# 30     37       0  -37
# 31     17      19    2
# 32     31       2  -29
# 33     49       9  -40
# 34     49       6  -43

# %%
fumo['|Dif|'] = fumo.Dif.abs()
fumo
# Out:
#     Antes  Depois  Dif  |Dif|
# 0      39      16  -23     23
# 1      25       8  -17     17
# 2      24      12  -12     12
# 3      50       0  -50     50
# 4      13      14    1      1
# 5      52      16  -36     36
# 6      21      13   -8      8
# 7      29      12  -17     17
# 8      10      19    9      9
# 9      22      17   -5      5
# 10     50      17  -33     33
# 11     15       2  -13     13
# 12     36      15  -21     21
# 13     39      10  -29     29
# 14     52      20  -32     32
# 15     48      13  -35     35
# 16     24       0  -24     24
# 17     15       4  -11     11
# 18     40      16  -24     24
# 19     41      18  -23     23
# 20     17      16   -1      1
# 21     12      16    4      4
# 22     21       9  -12     12
# 23     49       9  -40     40
# 24     14      18    4      4
# 25     55       4  -51     51
# 26     46      17  -29     29
# 27     22       0  -22     22
# 28     28      11  -17     17
# 29     23      14   -9      9
# ...

# %%
fumo.sort_values(by = '|Dif|', inplace = True)
fumo
# Out:
#     Antes  Depois  Dif  |Dif|
# 4      13      14    1      1
# 20     17      16   -1      1
# 31     17      19    2      2
# 21     12      16    4      4
# 24     14      18    4      4
# 9      22      17   -5      5
# 6      21      13   -8      8
# 29     23      14   -9      9
# 8      10      19    9      9
# 17     15       4  -11     11
# 2      24      12  -12     12
# 22     21       9  -12     12
# 11     15       2  -13     13
# 28     28      11  -17     17
# 1      25       8  -17     17
# 7      29      12  -17     17
# 12     36      15  -21     21
# 27     22       0  -22     22
# 19     41      18  -23     23
# 0      39      16  -23     23
# 16     24       0  -24     24
# 18     40      16  -24     24
# 26     46      17  -29     29
# 13     39      10  -29     29
# 32     31       2  -29     29
# 14     52      20  -32     32
# 10     50      17  -33     33
# 15     48      13  -35     35
# 5      52      16  -36     36
# 30     37       0  -37     37
# ...

# %%
fumo['Posto'] = range(1, len(fumo) + 1)
fumo
# Out:
#     Antes  Depois  Dif  |Dif|  Posto
# 4      13      14    1      1      1
# 20     17      16   -1      1      2
# 31     17      19    2      2      3
# 21     12      16    4      4      4
# 24     14      18    4      4      5
# 9      22      17   -5      5      6
# 6      21      13   -8      8      7
# 29     23      14   -9      9      8
# 8      10      19    9      9      9
# 17     15       4  -11     11     10
# 2      24      12  -12     12     11
# 22     21       9  -12     12     12
# 11     15       2  -13     13     13
# 28     28      11  -17     17     14
# 1      25       8  -17     17     15
# 7      29      12  -17     17     16
# 12     36      15  -21     21     17
# 27     22       0  -22     22     18
# 19     41      18  -23     23     19
# 0      39      16  -23     23     20
# 16     24       0  -24     24     21
# 18     40      16  -24     24     22
# 26     46      17  -29     29     23
# 13     39      10  -29     29     24
# ...

# %%
posto = fumo[['|Dif|', 'Posto']].groupby(['|Dif|']).mean()
posto
# Out:
#        Posto
# |Dif|
# 1        1.5
# 2        3.0
# 4        4.5
# 5        6.0
# 8        7.0
# 9        8.5
# 11      10.0
# 12      11.5
# 13      13.0
# 17      15.0
# 21      17.0
# 22      18.0
# 23      19.5
# 24      21.5
# 29      24.0
# 32      26.0
# 33      27.0
# 35      28.0
# 36      29.0
# 37      30.0
# 40      31.5
# 43      33.0
# 50      34.0
# 51      35.0

# %%
posto.reset_index(inplace = True)
posto
# Out:
#     |Dif|  Posto
# 0       1    1.5
# 1       2    3.0
# 2       4    4.5
# 3       5    6.0
# 4       8    7.0
# 5       9    8.5
# 6      11   10.0
# 7      12   11.5
# 8      13   13.0
# 9      17   15.0
# 10     21   17.0
# 11     22   18.0
# 12     23   19.5
# 13     24   21.5
# 14     29   24.0
# 15     32   26.0
# 16     33   27.0
# 17     35   28.0
# 18     36   29.0
# 19     37   30.0
# 20     40   31.5
# 21     43   33.0
# 22     50   34.0
# 23     51   35.0

# %%
fumo.drop(['Posto'], axis = 1, inplace = True)
fumo
# Out:
#     Antes  Depois  Dif  |Dif|
# 4      13      14    1      1
# 20     17      16   -1      1
# 31     17      19    2      2
# 21     12      16    4      4
# 24     14      18    4      4
# 9      22      17   -5      5
# 6      21      13   -8      8
# 29     23      14   -9      9
# 8      10      19    9      9
# 17     15       4  -11     11
# 2      24      12  -12     12
# 22     21       9  -12     12
# 11     15       2  -13     13
# 28     28      11  -17     17
# 1      25       8  -17     17
# 7      29      12  -17     17
# 12     36      15  -21     21
# 27     22       0  -22     22
# 19     41      18  -23     23
# 0      39      16  -23     23
# 16     24       0  -24     24
# 18     40      16  -24     24
# 26     46      17  -29     29
# 13     39      10  -29     29
# 32     31       2  -29     29
# 14     52      20  -32     32
# 10     50      17  -33     33
# 15     48      13  -35     35
# 5      52      16  -36     36
# 30     37       0  -37     37
# ...

# %%
fumo = fumo.merge(posto, left_on='|Dif|', right_on='|Dif|', how = 'left')
fumo
# Out:
#     Antes  Depois  Dif  |Dif|  Posto
# 0      13      14    1      1    1.5
# 1      17      16   -1      1    1.5
# 2      17      19    2      2    3.0
# 3      12      16    4      4    4.5
# 4      14      18    4      4    4.5
# 5      22      17   -5      5    6.0
# 6      21      13   -8      8    7.0
# 7      23      14   -9      9    8.5
# 8      10      19    9      9    8.5
# 9      15       4  -11     11   10.0
# 10     24      12  -12     12   11.5
# 11     21       9  -12     12   11.5
# 12     15       2  -13     13   13.0
# 13     28      11  -17     17   15.0
# 14     25       8  -17     17   15.0
# 15     29      12  -17     17   15.0
# 16     36      15  -21     21   17.0
# 17     22       0  -22     22   18.0
# 18     41      18  -23     23   19.5
# 19     39      16  -23     23   19.5
# 20     24       0  -24     24   21.5
# 21     40      16  -24     24   21.5
# 22     46      17  -29     29   24.0
# 23     39      10  -29     29   24.0
# ...

# %%
fumo['Posto (+)'] = fumo.apply(lambda x: x.Posto if x.Dif > 0 else 0, axis = 1)
fumo
# Out:
#     Antes  Depois  Dif  |Dif|  Posto  Posto (+)
# 0      13      14    1      1    1.5        1.5
# 1      17      16   -1      1    1.5        0.0
# 2      17      19    2      2    3.0        3.0
# 3      12      16    4      4    4.5        4.5
# 4      14      18    4      4    4.5        4.5
# 5      22      17   -5      5    6.0        0.0
# 6      21      13   -8      8    7.0        0.0
# 7      23      14   -9      9    8.5        0.0
# 8      10      19    9      9    8.5        8.5
# 9      15       4  -11     11   10.0        0.0
# 10     24      12  -12     12   11.5        0.0
# 11     21       9  -12     12   11.5        0.0
# 12     15       2  -13     13   13.0        0.0
# 13     28      11  -17     17   15.0        0.0
# 14     25       8  -17     17   15.0        0.0
# 15     29      12  -17     17   15.0        0.0
# 16     36      15  -21     21   17.0        0.0
# 17     22       0  -22     22   18.0        0.0
# 18     41      18  -23     23   19.5        0.0
# ...

# %%
fumo['Posto (-)'] = fumo.apply(lambda x: x.Posto if x.Dif < 0 else 0, axis = 1)
fumo
# Out:
#     Antes  Depois  Dif  |Dif|  Posto  Posto (+)  Posto (-)
# 0      13      14    1      1    1.5        1.5        0.0
# 1      17      16   -1      1    1.5        0.0        1.5
# 2      17      19    2      2    3.0        3.0        0.0
# 3      12      16    4      4    4.5        4.5        0.0
# 4      14      18    4      4    4.5        4.5        0.0
# 5      22      17   -5      5    6.0        0.0        6.0
# 6      21      13   -8      8    7.0        0.0        7.0
# 7      23      14   -9      9    8.5        0.0        8.5
# 8      10      19    9      9    8.5        8.5        0.0
# 9      15       4  -11     11   10.0        0.0       10.0
# 10     24      12  -12     12   11.5        0.0       11.5
# 11     21       9  -12     12   11.5        0.0       11.5
# 12     15       2  -13     13   13.0        0.0       13.0
# 13     28      11  -17     17   15.0        0.0       15.0
# 14     25       8  -17     17   15.0        0.0       15.0
# ...

# %%
fumo.drop(['Posto'], axis = 1, inplace = True)
fumo
# Out:
#     Antes  Depois  Dif  |Dif|  Posto (+)  Posto (-)
# 0      13      14    1      1        1.5        0.0
# 1      17      16   -1      1        0.0        1.5
# 2      17      19    2      2        3.0        0.0
# 3      12      16    4      4        4.5        0.0
# 4      14      18    4      4        4.5        0.0
# 5      22      17   -5      5        0.0        6.0
# 6      21      13   -8      8        0.0        7.0
# 7      23      14   -9      9        0.0        8.5
# 8      10      19    9      9        8.5        0.0
# 9      15       4  -11     11        0.0       10.0
# 10     24      12  -12     12        0.0       11.5
# 11     21       9  -12     12        0.0       11.5
# 12     15       2  -13     13        0.0       13.0
# 13     28      11  -17     17        0.0       15.0
# 14     25       8  -17     17        0.0       15.0
# 15     29      12  -17     17        0.0       15.0
# 16     36      15  -21     21        0.0       17.0
# ...

# %% [markdown]
#  Obter $T$
#
#  $T$ = menor das somas de postos de mesmo sinal

# %%
T = min(fumo['Posto (+)'].sum(), fumo['Posto (-)'].sum())
T
# Out:
# 22.0

# %% [markdown]
#  Obter $\mu_T$
#
#  $$\mu_T = \frac{n(n+1)}{4}$$

# %%
mu_T = (n * (n + 1)) / 4
mu_T
# Out:
# 315.0

# %% [markdown]
#  Obter $\sigma_T$
#
#  $$\sigma_T = \sqrt{\frac{n(n + 1)(2n + 1)}{24}}$$

# %%
sigma_T = np.sqrt((n * (n + 1) * ((2 * n) + 1)) / 24)
sigma_T
# Out:
# 61.053255441458646

# %% [markdown]
#  Obter $Z_{teste}$
#
#  $$Z = \frac{T - \mu_T}{\sigma_T}$$

# %%
Z = (T - mu_T) / sigma_T
Z
# Out:
# -4.799088891843698

# %% [markdown]
# ![Estatística-Teste](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img021.png)

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 5**
#
# Aceitação ou rejeição da hipótese nula

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img022.png' width='80%'>

# %% [markdown]
# ### <font color='red'>Critério do valor crítico</font>
#
# > ### Rejeitar $H_0$ se $Z \leq -z_{\alpha / 2}$ ou se $Z \geq z_{\alpha / 2}$

# %%
Z <= -z_alpha_2
# Out:
# True

# %%
Z >= z_alpha_2
# Out:
# False

# %% [markdown]
# <font color='green'>Conclusão: Rejeitamos a hipótese de que não existe diferença entre os grupos, isto é, existe uma diferença entre as médias de cigarros fumados pelos pacientes antes e depois do tratamento. E como é possível verificar através das médias de cigarros fumados por dia antes (31.86) e depois (11.2) do tratamento, podemos concluir que o tratamento apresentou resultado satisfatório.</font>

# %% [markdown]
# ### <font color='red'>Critério do valor $p$</font>
#
# > ### Rejeitar $H_0$ se o valor $p\leq\alpha$

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wilcoxon.html

# %%
from scipy.stats import wilcoxon

# %%
T, p_valor = wilcoxon(fumo.Antes, fumo.Depois)
print(T)
print(p_valor)
# Out:
# 22.0
# 3.119930624961853e-08

# %%
p_valor <= significancia
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Teste de Mann-Whitney</font>
# Comparação de duas populações - amostras independentes
# ***

# %% [markdown]
# Mann-Whitney é um teste não paramétrico utilizado para verificar se duas amostras independentes foram selecionadas a partir de populações que têm a mesma média. Por ser um teste não paramétrico, Mann-Whitney torna-se uma alternativa ao teste paramétrico de comparação de médias.

# %% [markdown]
# ### Seleção das amostras

# %%
mulheres = dados.query('Sexo == 1 and Renda > 0').sample(n = 8, random_state = 101).Renda

# %%
homens = dados.query('Sexo == 0 and Renda > 0').sample(n = 6, random_state = 101).Renda

# %% [markdown]
# ### Dados do problema

# %%
media_amostra_M = mulheres.mean()
media_amostra_M
# Out:
# 1090.75

# %%
media_amostra_H = homens.mean()
media_amostra_H
# Out:
# 1341.6666666666667

# %%
significancia = 0.05
confianca = 1 - significancia
n_1 = len(homens)
n_2 = len(mulheres)

# %% [markdown]
# ### **Passo 1** - formulação das hipóteses $H_0$ e $H_1$
#
# #### <font color='red'>Lembre-se, a hipótese nula sempre contém a alegação de igualdade</font>

# %% [markdown]
#  $\mu_m \Rightarrow$ Média das rendas dos chefes de domicílios do sexo feminino
#  $\mu_h \Rightarrow$ Média das rendas dos chefes de domicílios do sexo masculino
#
#  $
# \begin{cases}
# H_0: \mu_m = \mu_h\\
# H_1: \mu_m < \mu_h
# \end{cases}
# $

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 2** - escolha da distribuição amostral adequada

# %% [markdown]
# Deve-se optar pela distribuição **$t$ de Student**, já que nada é mencionado sobre a distribuição da população, o desvio padrão populacional é desconhecido e o número de elementos investigados é menor que 30.

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 3** - fixação da significância do teste ($\alpha$)

# %% [markdown]
#  Obtendo $t_{\alpha}$

# %%
graus_de_liberdade = n_1 + n_2 - 2
graus_de_liberdade
# Out:
# 12

# %%
tabela_t_student[10:13]
# Out:
# Bicaudal                          0.100     0.090     0.080     0.070  \
# Unicaudal                         0.050     0.045     0.040     0.035
# Graus de Liberdade (n - 1) 11  1.795885  1.858772  1.928427  2.006663
#                            12  1.782288  1.844015  1.912313  1.988934
#                            13  1.770933    1.8317  1.898874  1.974158
#
# Bicaudal                          0.060     0.050     0.040     0.030  \
# Unicaudal                         0.030     0.025     0.020     0.015
# Graus de Liberdade (n - 1) 11  2.096139  2.200985   2.32814  2.490664
#                            12  2.076441  2.178813  2.302722    2.4607
#                            13  2.060038  2.160369  2.281604  2.435845
#
# Bicaudal                          0.020     0.010
# Unicaudal                         0.010     0.005
# Graus de Liberdade (n - 1) 11  2.718079  3.105807
#                            12  2.680998   3.05454
#                            13  2.650309  3.012276

# %%
t_alpha = t_student.ppf(significancia, graus_de_liberdade)
t_alpha.round(2)
# Out:
# -1.78

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img023.png)

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 4** - cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste
# ## 1. Definir os n's:
# ### $n_1$ = nº de elementos do menor grupo
# ### $n_2$ = nº de elementos do maior grupo
# ---
# ## 2. Obter a soma dos postos
# ### $R_1$ = soma dos postos do grupo $n_1$
# ### $R_2$ = soma dos postos do grupo $n_2$
# ---
# ## 3. Obter as estatísticas
# # $$u_1 = n_1 \times n_2 + \frac{n_1 \times (n_1 + 1)}{2} - R_1$$
# # $$u_2 = n_1 \times n_2 + \frac{n_2 \times (n_2 + 1)}{2} - R_2$$
# ---
# ## 4. Selecionar o menor U
# # $$u = min(u_1, u_2)$$
# ---
# ## 5. Obter a estatística de teste
# # $$Z = \frac{u - \mu{(u)}}{\sigma{(u)}}$$
#
# Onde
#
# # $$\mu{(u)} = \frac{n_1 \times n_2}{2}$$
# # $$\sigma{(u)} = \sqrt{\frac{n_1 \times n_2 \times (n_1 + n_2 + 1)}{12}}$$

# %% [markdown]
#  Obtendo os postos

# %%
H = pd.DataFrame(homens)
H['Sexo'] = 'Homens'
H
# Out:
#        Renda    Sexo
# 67872   1200  Homens
# 30211   2000  Homens
# 64406    850  Homens
# 26519    800  Homens
# 61540   2000  Homens
# 17422   1200  Homens

# %%
M = pd.DataFrame(mulheres)
M['Sexo'] = 'Mulheres'
M
# Out:
#        Renda      Sexo
# 6251    1100  Mulheres
# 34764    400  Mulheres
# 40596    788  Mulheres
# 11303   4300  Mulheres
# 22733    250  Mulheres
# 24707    400  Mulheres
# 60340    700  Mulheres
# 17035    788  Mulheres

# %%
sexo = pd.concat([H, M], ignore_index=True)
sexo.reset_index(inplace = True, drop = True)
sexo
# Out:
#     Renda      Sexo
# 0    1200    Homens
# 1    2000    Homens
# 2     850    Homens
# 3     800    Homens
# 4    2000    Homens
# 5    1200    Homens
# 6    1100  Mulheres
# 7     400  Mulheres
# 8     788  Mulheres
# 9    4300  Mulheres
# 10    250  Mulheres
# 11    400  Mulheres
# 12    700  Mulheres
# 13    788  Mulheres

# %%
sexo.sort_values(by = 'Renda', inplace = True)
sexo
# Out:
#     Renda      Sexo
# 10    250  Mulheres
# 7     400  Mulheres
# 11    400  Mulheres
# 12    700  Mulheres
# 8     788  Mulheres
# 13    788  Mulheres
# 3     800    Homens
# 2     850    Homens
# 6    1100  Mulheres
# 0    1200    Homens
# 5    1200    Homens
# 1    2000    Homens
# 4    2000    Homens
# 9    4300  Mulheres

# %%
sexo['Posto'] = range(1, len(sexo) + 1)
sexo
# Out:
#     Renda      Sexo  Posto
# 10    250  Mulheres      1
# 7     400  Mulheres      2
# 11    400  Mulheres      3
# 12    700  Mulheres      4
# 8     788  Mulheres      5
# 13    788  Mulheres      6
# 3     800    Homens      7
# 2     850    Homens      8
# 6    1100  Mulheres      9
# 0    1200    Homens     10
# 5    1200    Homens     11
# 1    2000    Homens     12
# 4    2000    Homens     13
# 9    4300  Mulheres     14

# %%
posto = sexo[['Renda', 'Posto']].groupby(['Renda']).mean()
posto
# Out:
#        Posto
# Renda
# 250      1.0
# 400      2.5
# 700      4.0
# 788      5.5
# 800      7.0
# 850      8.0
# 1100     9.0
# 1200    10.5
# 2000    12.5
# 4300    14.0

# %%
posto.reset_index(inplace = True)
posto
# Out:
#    Renda  Posto
# 0    250    1.0
# 1    400    2.5
# 2    700    4.0
# 3    788    5.5
# 4    800    7.0
# 5    850    8.0
# 6   1100    9.0
# 7   1200   10.5
# 8   2000   12.5
# 9   4300   14.0

# %%
sexo.drop(['Posto'], axis = 1, inplace = True)
sexo
# Out:
#     Renda      Sexo
# 10    250  Mulheres
# 7     400  Mulheres
# 11    400  Mulheres
# 12    700  Mulheres
# 8     788  Mulheres
# 13    788  Mulheres
# 3     800    Homens
# 2     850    Homens
# 6    1100  Mulheres
# 0    1200    Homens
# 5    1200    Homens
# 1    2000    Homens
# 4    2000    Homens
# 9    4300  Mulheres

# %%
sexo = sexo.merge(posto, left_on='Renda', right_on='Renda', how = 'left')
sexo
# Out:
#     Renda      Sexo  Posto
# 0     250  Mulheres    1.0
# 1     400  Mulheres    2.5
# 2     400  Mulheres    2.5
# 3     700  Mulheres    4.0
# 4     788  Mulheres    5.5
# 5     788  Mulheres    5.5
# 6     800    Homens    7.0
# 7     850    Homens    8.0
# 8    1100  Mulheres    9.0
# 9    1200    Homens   10.5
# 10   1200    Homens   10.5
# 11   2000    Homens   12.5
# 12   2000    Homens   12.5
# 13   4300  Mulheres   14.0

# %% [markdown]
#  Obtendo $R$
#
#  $R_1$ = soma dos postos do grupo $n_1$
#  $R_2$ = soma dos postos do grupo $n_2$

# %%
Temp = sexo[['Sexo', 'Posto']].groupby('Sexo').sum()
Temp
# Out:
#           Posto
# Sexo
# Homens     61.0
# Mulheres   44.0

# %%
R_1 = Temp.loc['Homens'][0]
R_1
# Out:
# <ipython-input-127-552f640f1e83>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   R_1 = Temp.loc['Homens'][0]
# 61.0

# %%
R_2 = Temp.loc['Mulheres'][0]
R_2
# Out:
# <ipython-input-128-eee890ab2ea1>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   R_2 = Temp.loc['Mulheres'][0]
# 44.0

# %% [markdown]
#  Obter $u$
#
#  $$u_1 = n_1 \times n_2 + \frac{n_1 \times (n_1 + 1)}{2} - R_1$$
#  $$u_2 = n_1 \times n_2 + \frac{n_2 \times (n_2 + 1)}{2} - R_2$$
#
#  $$u = min(u_1, u_2)$$

# %%
u_1 = n_1 * n_2 + ((n_1 * (n_1 + 1)) / (2)) - R_1
u_1
# Out:
# 8.0

# %%
u_2 = n_1 * n_2 + ((n_2 * (n_2 + 1)) / (2)) - R_2
u_2
# Out:
# 40.0

# %%
u = min(u_1, u_2)
u
# Out:
# 8.0

# %% [markdown]
#  Obter $\mu{(u)}$
#
#  $$\mu{(u)} = \frac{n_1 \times n_2}{2}$$

# %%
mu_u = (n_1 * n_2) / 2
mu_u
# Out:
# 24.0

# %% [markdown]
#  Obter $\sigma{(u)}$
#
#  $$\sigma{(u)} = \sqrt{\frac{n_1 \times n_2 \times (n_1 + n_2 + 1)}{12}}$$

# %%
sigma_u = np.sqrt(n_1 * n_2 * (n_1 + n_2 + 1) / 12)
sigma_u
# Out:
# 7.745966692414834

# %% [markdown]
#  Obter $Z$
#
#  $$Z = \frac{u - \mu{(u)}}{\sigma{(u)}}$$

# %%
Z = (u - mu_u) / sigma_u
Z.round(2)
# Out:
# -2.07

# %% [markdown]
# ![Estatística-Teste](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img024.png)

# %% [markdown]
# ---

# %% [markdown]
# ### **Passo 5** - Aceitação ou rejeição da hipótese nula

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img025.png' width='80%'>

# %% [markdown]
# ### <font color='red'>Critério do valor crítico</font>
#
# > ### Rejeitar $H_0$ se $Z \leq -t_{\alpha}$

# %%
Z <= t_alpha
# Out:
# True

# %% [markdown]
#  <font color='green'>Conclusão: Rejeitamos a hipótese de que não existe diferença entre os grupos, isto é, concluímos que a média das rendas dos chefes de domicílios do sexo feminino é menor que a média das rendas dos chefes de domicílios do sexo masculino. Confirmando a alegação de desigualdade de renda entre os sexos.</font>

# %% [markdown]
# ### <font color='red'>Critério do valor $p$</font>
#
# > ### Rejeitar $H_0$ se o valor $p\leq\alpha$

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html

# %%
from scipy.stats import mannwhitneyu

# %%
u, p_valor = mannwhitneyu(mulheres, homens, alternative='less')
print(u)
print(p_valor)
# Out:
# 8.0
# 0.022221119551528605

# %%
p_valor <= significancia
# Out:
# True

# %% [markdown]
# ---
